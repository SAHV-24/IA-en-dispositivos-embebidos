# %%
import tensorflow as tf
import numpy as np
import cv2

# %%
interpreter = tf.lite.Interpreter(model_path="project_model.tflite")


interpreter.allocate_tensors() # Reserve in memory.

interpreter.get_input_details()
# Out:
# [{'name': 'serving_default_keras_tensor_154:0',
#   'index': 0,
#   'shape': array([  1, 224, 224,   3], dtype=int32),
#   'shape_signature': array([ -1, 224, 224,   3], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}}]

# %% [markdown]
# # Output Details:

# %%
output_details = interpreter.get_output_details()
output_details
# Out:
# [{'name': 'StatefulPartitionedCall_1:0',
#   'index': 180,
#   'shape': array([1, 6], dtype=int32),
#   'shape_signature': array([-1,  6], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}}]
